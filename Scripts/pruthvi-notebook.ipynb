# %%
# Mounting your personal Gdrive to the Colab notebook
from google.colab import drive
drive.mount('/gdrive',force_remount=True)

# %%
import pandas as pd

# %% [markdown]
# #AQI Data
#
# Unique join keys - 1062567
#
# No. of California unique keys- 58835

# %%
# Reading
aqi_cbsa_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2021.csv', index_col=0)
aqi_cbsa_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2020.csv', index_col=0)
aqi_cbsa_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2019.csv', index_col=0)
aqi_cbsa_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2018.csv', index_col=0)

aqi_cbsa_data_17 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2017.csv', index_col=0)
aqi_cbsa_data_16 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2016.csv', index_col=0)
aqi_cbsa_data_15 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2015.csv', index_col=0)
aqi_cbsa_data_14 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2014.csv', index_col=0)

aqi_cbsa_data_13 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2013.csv', index_col=0)
aqi_cbsa_data_12 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2012.csv', index_col=0)
aqi_cbsa_data_11 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2011.csv', index_col=0)
aqi_cbsa_data_10 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2010.csv', index_col=0)

aqi_cbsa_data = aqi_cbsa_data_21.append(aqi_cbsa_data_20)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_19)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_18)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_17)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_16)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_15)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_14)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_13)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_12)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_11)
aqi_cbsa_data = aqi_cbsa_data.append(aqi_cbsa_data_10)

aqi_cbsa_data.reset_index(level=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de6f67a4862d> in <module>()
#       1 # Reading
# ----> 2 aqi_cbsa_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2021.csv', index_col=0)
#       3 aqi_cbsa_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2020.csv', index_col=0)
#       4 aqi_cbsa_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2019.csv', index_col=0)
#       5 aqi_cbsa_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_cbsa_2018.csv', index_col=0)
#
# NameError: name 'pd' is not defined

# %%
aqi_cbsa_data.to_csv('/gdrive/My Drive/CDSS-Hackathon-21/garda_data.csv', index=False)

# %%
# Reading
aqi_county_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2021.csv', index_col=0)
aqi_county_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2020.csv', index_col=0)
aqi_county_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2019.csv', index_col=0)
aqi_county_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2018.csv', index_col=0)

aqi_county_data_17 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2017.csv', index_col=0)
aqi_county_data_16 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2016.csv', index_col=0)
aqi_county_data_15 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2015.csv', index_col=0)
aqi_county_data_14 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2014.csv', index_col=0)

aqi_county_data_13 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2013.csv', index_col=0)
aqi_county_data_12 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2012.csv', index_col=0)
aqi_county_data_11 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2011.csv', index_col=0)
aqi_county_data_10 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_aqi_by_county_2010.csv', index_col=0)

aqi_county_data = aqi_county_data_21.append(aqi_county_data_20)
aqi_county_data = aqi_county_data.append(aqi_county_data_19)
aqi_county_data = aqi_county_data.append(aqi_county_data_18)
aqi_county_data = aqi_county_data.append(aqi_county_data_17)
aqi_county_data = aqi_county_data.append(aqi_county_data_16)
aqi_county_data = aqi_county_data.append(aqi_county_data_15)
aqi_county_data = aqi_county_data.append(aqi_county_data_14)
aqi_county_data = aqi_county_data.append(aqi_county_data_13)
aqi_county_data = aqi_county_data.append(aqi_county_data_12)
aqi_county_data = aqi_county_data.append(aqi_county_data_11)
aqi_county_data = aqi_county_data.append(aqi_county_data_10)

aqi_county_data.reset_index(level=0, inplace=True)

# %%
# Standardizing Column names
# CO AQ
aqi_county_data.columns = aqi_county_data.columns.str.replace(' ', '_') # replacing spaces (' ') with  underscore.
aqi_county_data.columns = aqi_county_data.columns.str.replace('-', '_') # replacing hyphens ('-') with underscore
aqi_county_data.columns= aqi_county_data.columns.str.lower() # converting column names to lower case

# %%
aqi_county_data['join_key'] = aqi_county_data[['state_code', 'county_code', 'date']].apply(lambda x: '*'.join(x.dropna().astype(str).values), axis=1)

# %%
aqi_county_data.columns
# Out:
# Index(['state_name', 'county_name', 'state_code', 'county_code', 'date', 'aqi',
#        'category', 'defining_parameter', 'defining_site',
#        'number_of_sites_reporting', 'join_key'],
#       dtype='object')

# %%
aqi_county_data.to_gbq(destination_table= 'aqi_data.aqi_county_data_18_21', 
          project_id='cdss-datathon-327823', 
          if_exists='replace', 
          progress_bar=True)
# Out:
# 1it [00:32, 32.28s/it]

# %% [markdown]
# # CO Data
#
# Unique join keys - 177629
#
# No. of California unique keys- 27849

# %%
# Reading
co_aq_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42101_2021.csv', index_col=0)
co_aq_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42101_2020.csv', index_col=0)
co_aq_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42101_2019.csv', index_col=0)
co_aq_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42101_2018.csv', index_col=0)

co_aq_data = co_aq_data_21.append(co_aq_data_20)
co_aq_data = co_aq_data.append(co_aq_data_19)
co_aq_data = co_aq_data.append(co_aq_data_18)

co_aq_data.reset_index(level=0, inplace=True)

# %%
# Standardizing Column names
# CO AQ
co_aq_data.columns = co_aq_data.columns.str.replace(' ', '_') # replacing spaces (' ') with  underscore.
co_aq_data.columns = co_aq_data.columns.str.replace('-', '_') # replacing hyphens ('-') with underscore
co_aq_data.columns= co_aq_data.columns.str.lower() # converting column names to lower case

# %%
co_aq_data.columns= ['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
       'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
       'pollutant_standard', 'date_local', 'units_of_measure', 'event_type',
       'observation_count', 'observation_percent', 'arithmetic_mean',
       'lst_max_value', 'lst_max_hour', 'aqi', 'method_code', 'method_name',
       'local_site_name', 'address', 'state_name', 'county_name', 'city_name',
       'cbsa_name', 'date_of_last_change']

# %%
co_aq_data['join_key'] = co_aq_data[['state_code', 'county_code', 'date_local']].apply(lambda x: '*'.join(x.dropna().astype(str).values), axis=1)

# %%
co_aq_data.to_gbq(destination_table= 'aqi_data.co_aq_data_18_21', 
          project_id='cdss-datathon-327823', 
          if_exists='replace', 
          progress_bar=True)
# Out:
# 1it [00:49, 49.91s/it]

# %% [markdown]
# #SO2 Data
# Unique join keys - 184040
#
# No. of California unique keys- 27756

# %%
# Reading
so2_aq_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42401_2021.csv', index_col=0)
so2_aq_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42401_2020.csv', index_col=0)
so2_aq_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42401_2019.csv', index_col=0)
so2_aq_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_42401_2018.csv', index_col=0)

so2_aq_data = so2_aq_data_21.append(co_aq_data_20)
so2_aq_data = so2_aq_data.append(co_aq_data_19)
so2_aq_data = so2_aq_data.append(co_aq_data_18)

so2_aq_data.reset_index(level=0, inplace=True)

# %%
# Standardizing Column names
# CO AQ
so2_aq_data.columns = so2_aq_data.columns.str.replace(' ', '_') # replacing spaces (' ') with  underscore.
so2_aq_data.columns = so2_aq_data.columns.str.replace('-', '_') # replacing hyphens ('-') with underscore
so2_aq_data.columns= so2_aq_data.columns.str.lower() # converting column names to lower case

# %%
so2_aq_data.columns= ['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
       'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
       'pollutant_standard', 'date_local', 'units_of_measure', 'event_type',
       'observation_count', 'observation_percent', 'arithmetic_mean',
       'lst_max_value', 'lst_max_hour', 'aqi', 'method_code', 'method_name',
       'local_site_name', 'address', 'state_name', 'county_name', 'city_name',
       'cbsa_name', 'date_of_last_change']

# %%
so2_aq_data['join_key'] = so2_aq_data[['state_code', 'county_code', 'date_local']].apply(lambda x: '*'.join(x.dropna().astype(str).values), axis=1)

# %%
so2_aq_data.to_gbq(destination_table= 'aqi_data.so2_aq_data_18_21', 
          project_id='cdss-datathon-327823', 
          if_exists='replace', 
          progress_bar=True)
# Out:
# 1it [01:18, 78.20s/it]

# %% [markdown]
# #OZ Data
#
# Unique join keys - 26291
#
# No. of California unique keys- 1102

# %%
# Reading
oz_aq_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_44201_2021.csv', index_col=0)
oz_aq_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_44201_2021.csv', index_col=0)
oz_aq_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_44201_2021.csv', index_col=0)
oz_aq_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_44201_2021.csv', index_col=0)

oz_aq_data = oz_aq_data_21.append(oz_aq_data_20)
oz_aq_data = oz_aq_data.append(oz_aq_data_19)
oz_aq_data = oz_aq_data.append(oz_aq_data_18)

oz_aq_data.reset_index(level=0, inplace=True)

# %%
# Standardizing Column names
# CO AQ
oz_aq_data.columns = oz_aq_data.columns.str.replace(' ', '_') # replacing spaces (' ') with  underscore.
oz_aq_data.columns = oz_aq_data.columns.str.replace('-', '_') # replacing hyphens ('-') with underscore
oz_aq_data.columns= oz_aq_data.columns.str.lower() # converting column names to lower case

# %%
oz_aq_data.columns= ['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
       'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
       'pollutant_standard', 'date_local', 'units_of_measure', 'event_type',
       'observation_count', 'observation_percent', 'arithmetic_mean',
       'lst_max_value', 'lst_max_hour', 'aqi', 'method_code', 'method_name',
       'local_site_name', 'address', 'state_name', 'county_name', 'city_name',
       'cbsa_name', 'date_of_last_change']

# %%
oz_aq_data['join_key'] = oz_aq_data[['state_code', 'county_code', 'date_local']].apply(lambda x: '*'.join(x.dropna().astype(str).values), axis=1)

# %%
oz_aq_data.to_gbq(destination_table= 'aqi_data.oz_aq_data_18_21', 
          project_id='cdss-datathon-327823', 
          if_exists='replace', 
          progress_bar=True)
# Out:
# 1it [00:25, 25.48s/it]

# %% [markdown]
# # PM2.5 Data
#
# Unique join keys - 162445
#
# No. of California unique keys- 18072

# %%
# Reading
pm2_aq_data_21 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_SPEC_2021.csv', index_col=0)
pm2_aq_data_20 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_SPEC_2020.csv', index_col=0)
pm2_aq_data_19 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_SPEC_2019.csv', index_col=0)
pm2_aq_data_18 = pd.read_csv('/gdrive/My Drive/CDSS-Hackathon-21/EPA-AQI/daily_SPEC_2018.csv', index_col=0)

pm2_aq_data = pm2_aq_data_21.append(pm2_aq_data_20)
pm2_aq_data = pm2_aq_data.append(pm2_aq_data_19)
pm2_aq_data = pm2_aq_data.append(pm2_aq_data_18)

pm2_aq_data.reset_index(level=0, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# Standardizing Column names
# PM 2.5 
pm2_aq_data.columns = pm2_aq_data.columns.str.replace(' ', '_') # replacing spaces (' ') with  underscore.
pm2_aq_data.columns = pm2_aq_data.columns.str.replace('-', '_') # replacing hyphens ('-') with underscore
pm2_aq_data.columns= pm2_aq_data.columns.str.lower() # converting column names to lower case

# %%
pm2_aq_data.columns= ['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
       'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
       'pollutant_standard', 'date_local', 'units_of_measure', 'event_type',
       'observation_count', 'observation_percent', 'arithmetic_mean',
       'lst_max_value', 'lst_max_hour', 'aqi', 'method_code', 'method_name',
       'local_site_name', 'address', 'state_name', 'county_name', 'city_name',
       'cbsa_name', 'date_of_last_change']

# %%
pm2_aq_data['join_key'] = pm2_aq_data[['state_code', 'county_code', 'date_local']].apply(lambda x: '*'.join(x.dropna().astype(str).values), axis=1)

# %%
pm2_aq_data.to_gbq(destination_table= 'aqi_data.pm2_aq_data_18_21', 
          project_id='cdss-datathon-327823', 
          if_exists='replace', 
          progress_bar=True)
# Out:
# 1it [07:05, 425.68s/it]

# %% [markdown]
# # AQI Master data - Joining

# %%
#AQI
aqi_county_data_jo = aqi_county_data[['state_name', 'county_name', 'state_code', 'county_code', 'date', 'aqi',
                                    'category', 'join_key']]

# CO
co_aq_data_jo = co_aq_data[['join_key','latitude', 'longitude','units_of_measure','arithmetic_mean',
                          'lst_max_value', 'lst_max_hour', 'aqi']]
co_aq_data_jo.columns = ['join_key','co_latitude', 'co_longitude','co_units_of_measure','co_arithmetic_mean',
                          'co_lst_max_value', 'co_lst_max_hour', 'co_aqi']

# SO2
so2_aq_data_jo = so2_aq_data[['join_key','latitude', 'longitude','units_of_measure','arithmetic_mean',
                          'lst_max_value', 'lst_max_hour', 'aqi']]
so2_aq_data_jo.columns = ['join_key','so2_latitude', 'so2_longitude','so2_units_of_measure','so2_arithmetic_mean',
                          'so2_lst_max_value', 'so2_lst_max_hour', 'so2_aqi']

# OZ
oz_aq_data_jo = oz_aq_data[['join_key','latitude', 'longitude','units_of_measure','arithmetic_mean',
                          'lst_max_value', 'lst_max_hour', 'aqi']]
oz_aq_data_jo.columns = ['join_key','oz_latitude', 'oz_longitude','oz_units_of_measure','oz_arithmetic_mean',
                          'oz_lst_max_value', 'oz_lst_max_hour', 'oz_aqi']

#PM2
pm2_aq_data_jo = pm2_aq_data[['join_key','latitude', 'longitude','units_of_measure','arithmetic_mean',
                          'lst_max_value', 'lst_max_hour', 'aqi']]
pm2_aq_data_jo.columns = ['join_key','pm2_latitude', 'pm2_longitude','pm2_units_of_measure','pm2_arithmetic_mean',
                          'pm2_lst_max_value', 'pm2_lst_max_hour', 'pm2_aqi']

# %%
from functools import reduce

# List of dataframes to join 
data_frames = [aqi_county_data_jo, co_aq_data_jo, so2_aq_data_jo, oz_aq_data_jo, pm2_aq_data_jo]

# Join using the rduce function
aqi_master_data = reduce(lambda  left,right: pd.merge(left,right,on=['join_key'],
                                            how='left'), data_frames)

# %%
"""


SELECT
aqi.date,aqi.state_name, aqi.county_name, aqi.state_code, aqi.county_code, 
IFNULL(IFNULL(co.latitude,so.latitude),oz.latitude) as latitude,
IFNULL(IFNULL(co.longitude,so.longitude),oz.longitude) as longitude,
aqi.aqi, aqi.category, aqi.join_key,

co.units_of_measure as co_units_of_measure,co.arithmetic_mean as co_arithmetic_mean, 
co.lst_max_value as co_lst_max_value, co.lst_max_hour as co_lst_max_hour, co.aqi as co_aqi,

so.units_of_measure as so_units_of_measure,so.arithmetic_mean as so_arithmetic_mean, 
so.lst_max_value as so_lst_max_value, so.lst_max_hour as so_lst_max_hour, so.aqi as so_aqi,

oz.units_of_measure as oz_units_of_measure,oz.arithmetic_mean as oz_arithmetic_mean, 
oz.lst_max_value as oz_lst_max_value, oz.lst_max_hour as oz_lst_max_hour, oz.aqi as oz_aqi

#pm.units_of_measure as pm_units_of_measure,pm.arithmetic_mean as pm_arithmetic_mean, 
#pm.lst_max_value as pm_lst_max_value, pm.lst_max_hour as pm_lst_max_hour, pm.aqi as pm_aqi,


FROM `cdss-datathon-327823.aqi_data.aqi_county_data_18_21` aqi
LEFT JOIN (SELECT * FROM `cdss-datathon-327823.aqi_data.co_aq_data_18_21` WHERE method_name = ' - ') co
ON aqi.join_key = co.join_key
LEFT JOIN ( SELECT * FROM `cdss-datathon-327823.aqi_data.so2_aq_data_18_21` WHERE pollutant_standard = 'CO 8-hour 1971') so
ON aqi.join_key = so.join_key
LEFT JOIN (SELECT DISTINCT * FROM `cdss-datathon-327823.aqi_data.oz_aq_data_18_21`) oz
ON aqi.join_key = oz.join_key
#LEFT JOIN `cdss-datathon-327823.aqi_data.pm2_aq_data_18_21` pm
#ON aqi.join_key = pm.join_key


"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-add2578b04b6> in <module>()
# ----> 1 aqi_master_data.head(50)
#
# NameError: name 'aqi_master_data' is not defined
